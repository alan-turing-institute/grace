# %%
import networkx as nx
import matplotlib.pyplot as plt

from grace.base import GraphAttrs

from grace.simulator.simulate_graph import random_graph
from grace.simulator.simulate_image import synthesize_image_from_graph

# %%
G = random_graph(n_motifs=3, n_chaff=100, density=0.02, motif="lines")

# %%
G

# %%
pos = {idx: (node[GraphAttrs.NODE_X], node[GraphAttrs.NODE_Y]) for idx, node in G.nodes(data=True)}
fig, ax = plt.subplots(figsize=(8, 8))

nx.draw_networkx(G, pos=pos, with_labels=False, node_color="k", node_size=32)

# %%
image, graph = synthesize_image_from_graph(
    G=G,
    image_value=227,
    image_shape=(3500, 3500), 
    crop_shape=(224, 224),
    mask_shape=(112, 112)
)

# %%
plt.imshow(image)

# %%
import numpy as np

# %%
len(np.unique(image))
# Out:
# 3

# %% [markdown]
# # Testing that the graph gets created:

# %%
import pytest
